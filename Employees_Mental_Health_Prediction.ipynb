# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/survey.csv")
df
# Out:
#       index            Timestamp  Age  Gender         Country state  \
# 0         0  2014-08-27 11:29:31   37  Female   United States    IL
# 1         1  2014-08-27 11:29:37   44       M   United States    IN
# 2         2  2014-08-27 11:29:44   32    Male          Canada   NaN
# 3         3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN
# 4         4  2014-08-27 11:30:22   31    Male   United States    TX
# ...     ...                  ...  ...     ...             ...   ...
# 1254   1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN
# 1255   1255  2015-09-26 01:07:35   32    Male   United States    IL
# 1256   1256  2015-11-07 12:36:58   34    male   United States    CA
# 1257   1257  2015-11-30 21:25:06   46       f   United States    NC
# 1258   1258  2016-02-01 23:04:31   25    Male   United States    IL
#
#      self_employed family_history treatment work_interfere  ...  \
# 0              NaN             No       Yes          Often  ...
# ...

# %%
df.shape
# Out:
# (1259, 28)

# %%
df.isnull().sum()
# Out:
# index                           0
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(3)
# Out:
#    index            Timestamp  Age  Gender        Country state self_employed  \
# 0      0  2014-08-27 11:29:31   37  Female  United States    IL           NaN
# 1      1  2014-08-27 11:29:37   44       M  United States    IN           NaN
# 2      2  2014-08-27 11:29:44   32    Male         Canada   NaN           NaN
#
#   family_history treatment work_interfere  ...               leave  \
# 0             No       Yes          Often  ...       Somewhat easy
# 1             No        No         Rarely  ...          Don't know
# 2             No        No         Rarely  ...  Somewhat difficult
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# 0                        No                      No  Some of them        Yes
# 1                     Maybe                      No            No         No
# 2                        No                      No           Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# ...

# %%
df['Age'].value_counts()
# Out:
#  29             85
#  32             82
#  26             75
#  27             71
#  33             70
#  28             68
#  31             67
#  34             65
#  30             63
#  25             61
#  35             55
#  23             51
#  24             46
#  37             43
#  38             39
#  36             37
#  40             33
#  39             33
#  43             28
#  22             21
#  41             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  48              6
#  50              6
#  20              6
#  51              5
#  49              4
#  56              4
#  57              3
#  54              3
#  55              3
#  47              2
#  60              2
#  99999999999     1
#  5               1
# -1               1
#  11              1
#  8               1
#  61              1
#  53              1
# -29              1
# ...

# %%
df['Age']=df['Age'].replace([99999999999,-1,-29,-1726],[32,32,32,32])

# %%
df1=df.drop(['Timestamp','Gender','Country','state','comments','remote_work','seek_help','benefits','care_options','anonymity','index','supervisor','obs_consequence','mental_vs_physical'],axis='columns')

# %%
df1.head(3)
# Out:
#    Age self_employed family_history treatment work_interfere    no_employees  \
# 0   37           NaN             No       Yes          Often            6-25
# 1   44           NaN             No        No         Rarely  More than 1000
# 2   32           NaN             No        No         Rarely            6-25
#
#   tech_company wellness_program               leave mental_health_consequence  \
# 0          Yes               No       Somewhat easy                        No
# 1           No       Don't know          Don't know                     Maybe
# 2          Yes               No  Somewhat difficult                        No
#
#   phys_health_consequence     coworkers mental_health_interview  \
# 0                      No  Some of them                      No
# 1                      No            No                      No
# 2                      No           Yes                     Yes
#
#   phys_health_interview
# 0                 Maybe
# 1                    No
# ...

# %%
df1['self_employed'].unique()
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %%
df1['self_employed']=df1['self_employed'].fillna('Yes')

# %%
df2=df1.drop(['Age','self_employed','family_history','treatment','work_interfere','tech_company'],axis='columns')

# %%
df2
# Out:
#         no_employees wellness_program               leave  \
# 0               6-25               No       Somewhat easy
# 1     More than 1000       Don't know          Don't know
# 2               6-25               No  Somewhat difficult
# 3             26-100               No  Somewhat difficult
# 4            100-500       Don't know          Don't know
# ...              ...              ...                 ...
# 1254          26-100               No       Somewhat easy
# 1255          26-100               No  Somewhat difficult
# 1256  More than 1000               No  Somewhat difficult
# 1257         100-500               No          Don't know
# 1258          26-100               No          Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 0                           No                      No  Some of them
# 1                        Maybe                      No            No
# ...

# %%
df2['mental_health_consequence']=df['mental_health_consequence'].replace(["Maybe"],["No"])

# %%
df2['phys_health_consequence'].value_counts()
# Out:
# No       925
# Maybe    273
# Yes       61
# Name: phys_health_consequence, dtype: int64

# %%
df2['mental_health_consequence']=df2['mental_health_consequence'].replace(["Maybe"],["No"])

# %%
df3=df2.drop(['phys_health_consequence','phys_health_interview',],axis='columns')
df3
# Out:
#         no_employees wellness_program               leave  \
# 0               6-25               No       Somewhat easy
# 1     More than 1000       Don't know          Don't know
# 2               6-25               No  Somewhat difficult
# 3             26-100               No  Somewhat difficult
# 4            100-500       Don't know          Don't know
# ...              ...              ...                 ...
# 1254          26-100               No       Somewhat easy
# 1255          26-100               No  Somewhat difficult
# 1256  More than 1000               No  Somewhat difficult
# 1257         100-500               No          Don't know
# 1258          26-100               No          Don't know
#
#      mental_health_consequence     coworkers mental_health_interview
# 0                           No  Some of them                      No
# 1                           No            No                      No
# ...

# %%
df3['wellness_program'].value_counts()
# Out:
# No            842
# Yes           229
# Don't know    188
# Name: wellness_program, dtype: int64

# %%
df3['wellness_program']=df3['wellness_program'].replace(["Dont know"],"No")
df3.head()
# Out:
#      no_employees wellness_program               leave  \
# 0            6-25               No       Somewhat easy
# 1  More than 1000       Don't know          Don't know
# 2            6-25               No  Somewhat difficult
# 3          26-100               No  Somewhat difficult
# 4         100-500       Don't know          Don't know
#
#   mental_health_consequence     coworkers mental_health_interview
# 0                        No  Some of them                      No
# 1                        No            No                      No
# 2                        No           Yes                     Yes
# 3                       Yes  Some of them                   Maybe
# 4                        No  Some of them                     Yes

# %%
df3['leave'].value_counts()
# Out:
# Don't know            563
# Somewhat easy         266
# Very easy             206
# Somewhat difficult    126
# Very difficult         98
# Name: leave, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_leave=LabelEncoder()
df3.leave=le_leave.fit_transform(df3.leave)
df3
# Out:
#         no_employees wellness_program  leave mental_health_consequence  \
# 0               6-25               No      2                        No
# 1     More than 1000       Don't know      0                        No
# 2               6-25               No      1                        No
# 3             26-100               No      1                       Yes
# 4            100-500       Don't know      0                        No
# ...              ...              ...    ...                       ...
# 1254          26-100               No      2                        No
# 1255          26-100               No      1                        No
# 1256  More than 1000               No      1                       Yes
# 1257         100-500               No      0                       Yes
# 1258          26-100               No      0                        No
#
#          coworkers mental_health_interview
# 0     Some of them                      No
# ...

# %%
df["wellness_program"].value_counts()
# Out:
# No            842
# Yes           229
# Don't know    188
# Name: wellness_program, dtype: int64

# %%
le_wellness_program=LabelEncoder()
df3.wellness_program=le_wellness_program.fit_transform(df3.wellness_program)
df3.head(3)
# Out:
#      no_employees  wellness_program  leave mental_health_consequence  \
# 0            6-25                 1      2                        No
# 1  More than 1000                 0      0                        No
# 2            6-25                 1      1                        No
#
#       coworkers mental_health_interview
# 0  Some of them                      No
# 1            No                      No
# 2           Yes                     Yes

# %%
df['no_employees'].value_counts()
# Out:
# 6-25              290
# 26-100            289
# More than 1000    282
# 100-500           176
# 1-5               162
# 500-1000           60
# Name: no_employees, dtype: int64

# %%
np_list=pd.Series(df3['no_employees'].unique())
print(np_list)
# Out:
# 0              6-25
# 1    More than 1000
# 2            26-100
# 3           100-500
# 4               1-5
# 5          500-1000
# dtype: object

# %%
np_list2=np_list.str.findall('(\d+)')

# %%
np_list3=pd.Series([],dtype="float64")
for i in range(0,len(np_list2)):
  np_list2[i]=np.array(np_list2[i]).astype(np.float64)
  np_list3[i]=(sum(np_list2[i])/len(np_list2[i])).round()

# %%
np_list3
# Out:
# 0      16.0
# 1    1000.0
# 2      63.0
# 3     300.0
# 4       3.0
# 5     750.0
# dtype: float64

# %%
df3['no_employees']=np_list3

# %%
df3.head(3)
# Out:
#    no_employees  wellness_program  leave mental_health_consequence  \
# 0          16.0                 1      2                        No
# 1        1000.0                 0      0                        No
# 2          63.0                 1      1                        No
#
#       coworkers mental_health_interview
# 0  Some of them                      No
# 1            No                      No
# 2           Yes                     Yes

# %%
le_wellness_program=LabelEncoder()
df3.wellness_program=le_wellness_program.fit_transform(df3.wellness_program)
df3.head(3)
# Out:
#    no_employees  wellness_program  leave mental_health_consequence  \
# 0          16.0                 1      2                        No
# 1        1000.0                 0      0                        No
# 2          63.0                 1      1                        No
#
#       coworkers mental_health_interview
# 0  Some of them                      No
# 1            No                      No
# 2           Yes                     Yes

# %%
df['coworkers'].value_counts()
# Out:
# Some of them    774
# No              260
# Yes             225
# Name: coworkers, dtype: int64

# %%
le_cw=LabelEncoder()
df3.coworkers=le_cw.fit_transform(df3.coworkers)
df3.head(3)
# Out:
#    no_employees  wellness_program  leave mental_health_consequence  coworkers  \
# 0          16.0                 1      2                        No          1
# 1        1000.0                 0      0                        No          0
# 2          63.0                 1      1                        No          2
#
#   mental_health_interview
# 0                      No
# 1                      No
# 2                     Yes

# %%
le_mhi=LabelEncoder()
df3.mental_health_interview=le_mhi.fit_transform(df3.mental_health_interview)
df3.head(3)
# Out:
#    no_employees  wellness_program  leave mental_health_consequence  coworkers  \
# 0          16.0                 1      2                        No          1
# 1        1000.0                 0      0                        No          0
# 2          63.0                 1      1                        No          2
#
#    mental_health_interview
# 0                        1
# 1                        1
# 2                        2

# %%
df3['no_employees'].fillna(305)
# Out:
# 0         16.0
# 1       1000.0
# 2         63.0
# 3        300.0
# 4          3.0
#          ...
# 1254     305.0
# 1255     305.0
# 1256     305.0
# 1257     305.0
# 1258     305.0
# Name: no_employees, Length: 1259, dtype: float64

# %%
df3['wellness_program'].isnull().values.any()
# Out:
# False

# %%
df3['leave'].isnull().values.any()
# Out:
# False

# %%
df3['coworkers'].isnull().values.any()
# Out:
# False

# %%
df3['mental_health_interview'].isnull().values.any()
# Out:
# False

# %%
X=df3.drop('mental_health_consequence',axis='columns')
y=df3['mental_health_consequence']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
model=HistGradientBoostingClassifier(loss='log_loss',learning_rate=0.1,max_iter=20)
model.fit(X_train,y_train)
# Out:
# HistGradientBoostingClassifier(max_iter=20)

# %%
model.score(X_test,y_test)
# Out:
# 0.8015873015873016

# %%
pred=model.predict(X_test)

# %%
pred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
# ...

# %%
pdf=pd.DataFrame({'col':pred})
print(pdf)
# Out:
#     col
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# ..   ..
# 247  No
# 248  No
# 249  No
# 250  No
# 251  No
#
# [252 rows x 1 columns]
